# %%
import requests
import json

# %%
usr = "tourist"

# %%
res=requests.get("https://codeforces.com/api/user.status?handle="+usr).json()
res
# Out:
# {'status': 'OK',
#  'result': [{'id': 147518709,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655817,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 88,
#    'timeConsumedMillis': 2433,
#    'memoryConsumedBytes': 34201600},
#   {'id': 147518559,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655543,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'TIME_LIMIT_EXCEEDED',
#    'testset': 'TESTS',
#    'passedTestCount': 13,
#    'timeConsumedMillis': 3000,
#    'memoryConsumedBytes': 14336000},
#   {'id': 147518438,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655350,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 88,
#    'timeConsumedMillis': 2901,
#    'memoryConsumedBytes': 13209600},
#   {'id': 147518414,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655303,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 88,
#    'timeConsumedMillis': 2901,
#    'memoryConsumedBytes': 13209600},
#   {'id': 147518379,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655241,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'TIME_LIMIT_EXCEEDED',
#    'testset': 'TESTS',
#    'passedTestCount': 13,
#    'timeConsumedMillis': 3000,
#    'memoryConsumedBytes': 13209600},
#   {'id': 147518361,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645655203,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'TIME_LIMIT_EXCEEDED',
#    'testset': 'TESTS',
#    'passedTestCount': 13,
#    'timeConsumedMillis': 3000,
#    'memoryConsumedBytes': 13209600},
#   {'id': 147463572,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645617932,
#    'relativeTimeSeconds': 6932,
#    'problem': {'contestId': 1641,
#     'index': 'F',
#     'name': 'Covering Circle',
#     'type': 'PROGRAMMING',
#     'points': 3000.0,
#     'tags': ['geometry']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 38,
#    'timeConsumedMillis': 4664,
#    'memoryConsumedBytes': 6246400},
#   {'id': 147445838,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645614665,
#    'relativeTimeSeconds': 3665,
#    'problem': {'contestId': 1641,
#     'index': 'E',
#     'name': 'Special Positions',
#     'type': 'PROGRAMMING',
#     'points': 2250.0,
#     'tags': ['brute force',
#      'combinatorics',
#      'divide and conquer',
#      'fft',
#      'math']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 74,
#    'timeConsumedMillis': 202,
#    'memoryConsumedBytes': 6246400},
#   {'id': 147438181,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645613653,
#    'relativeTimeSeconds': 2653,
#    'problem': {'contestId': 1641,
#     'index': 'B',
#     'name': 'Repetitions Decoding',
#     'type': 'PROGRAMMING',
#     'points': 1250.0,
#     'tags': ['constructive algorithms',
#      'greedy',
#      'implementation',
#      'sortings']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 20,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 1126400},
#   {'id': 147435041,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645613291,
#    'relativeTimeSeconds': 2291,
#    'problem': {'contestId': 1641,
#     'index': 'C',
#     'name': 'Anonymity Is Important',
#     'type': 'PROGRAMMING',
#     'points': 1250.0,
#     'tags': ['binary search',
#      'brute force',
#      'data structures',
#      'dsu',
#      'greedy',
#      'sortings']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 50,
#    'timeConsumedMillis': 748,
#    'memoryConsumedBytes': 29184000},
#   {'id': 147427811,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645612579,
#    'relativeTimeSeconds': 1579,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 87,
#    'timeConsumedMillis': 2292,
#    'memoryConsumedBytes': 19865600},
#   {'id': 147420887,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645611960,
#    'relativeTimeSeconds': 960,
#    'problem': {'contestId': 1641,
#     'index': 'D',
#     'name': 'Two Arrays',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'tags': ['bitmasks',
#      'brute force',
#      'greedy',
#      'hashing',
#      'probabilities',
#      'two pointers']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'TIME_LIMIT_EXCEEDED',
#    'testset': 'PRETESTS',
#    'passedTestCount': 13,
#    'timeConsumedMillis': 3000,
#    'memoryConsumedBytes': 13209600},
#   {'id': 147414901,
#    'contestId': 1641,
#    'creationTimeSeconds': 1645611325,
#    'relativeTimeSeconds': 325,
#    'problem': {'contestId': 1641,
#     'index': 'A',
#     'name': 'Great Sequence',
#     'type': 'PROGRAMMING',
#     'points': 500.0,
#     'tags': ['brute force', 'greedy', 'sortings']},
#    'author': {'contestId': 1641,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 8,
#     'startTimeSeconds': 1645611000},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 38,
#    'timeConsumedMillis': 31,
#    'memoryConsumedBytes': 819200},
#   {'id': 146445328,
#    'contestId': 1638,
#    'creationTimeSeconds': 1644865885,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1638,
#     'index': 'E',
#     'name': 'Colorful Operations',
#     'type': 'PROGRAMMING',
#     'points': 2500.0,
#     'rating': 2400,
#     'tags': ['brute force', 'data structures', 'implementation']},
#    'author': {'contestId': 1638,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1644849300},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 84,
#    'timeConsumedMillis': 1278,
#    'memoryConsumedBytes': 22016000},
#   {'id': 146445294,
#    'contestId': 1638,
#    'creationTimeSeconds': 1644865878,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1638,
#     'index': 'D',
#     'name': 'Big Brush',
#     'type': 'PROGRAMMING',
#     'points': 1750.0,
#     'rating': 2000,
#     'tags': ['constructive algorithms',
#      'data structures',
#      'greedy',
#      'implementation']},
#    'author': {'contestId': 1638,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1644849300},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 51,
#    'timeConsumedMillis': 498,
#    'memoryConsumedBytes': 22630400},
#   {'id': 146445274,
#    'contestId': 1638,
#    'creationTimeSeconds': 1644865872,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1638,
#     'index': 'C',
#     'name': 'Inversion Graph',
#     'type': 'PROGRAMMING',
#     'points': 1250.0,
#     'rating': 1300,
#     'tags': ['data structures', 'dsu', 'graphs', 'math']},
#    'author': {'contestId': 1638,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1644849300},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 55,
#    'timeConsumedMillis': 46,
#    'memoryConsumedBytes': 819200},
#   {'id': 146445254,
#    'contestId': 1638,
#    'creationTimeSeconds': 1644865865,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1638,
#     'index': 'B',
#     'name': 'Odd Swap Sort',
#     'type': 'PROGRAMMING',
#     'points': 750.0,
#     'rating': 1100,
#     'tags': ['data structures', 'math', 'sortings']},
#    'author': {'contestId': 1638,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1644849300},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 82,
#    'timeConsumedMillis': 46,
#    'memoryConsumedBytes': 1638400},
#   {'id': 146445146,
#    'contestId': 1638,
#    'creationTimeSeconds': 1644865845,
#    'relativeTimeSeconds': 2147483647,
#    'problem': {'contestId': 1638,
#     'index': 'A',
#     'name': 'Reverse',
#     'type': 'PROGRAMMING',
#     'points': 500.0,
#     'rating': 800,
#     'tags': ['constructive algorithms', 'greedy', 'math']},
#    'author': {'contestId': 1638,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'PRACTICE',
#     'ghost': False,
#     'startTimeSeconds': 1644849300},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 14,
#    'timeConsumedMillis': 46,
#    'memoryConsumedBytes': 0},
#   {'id': 146151101,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644685151,
#    'relativeTimeSeconds': 8651,
#    'problem': {'contestId': 1637,
#     'index': 'H',
#     'name': 'Minimize Inversions Number',
#     'type': 'PROGRAMMING',
#     'points': 4000.0,
#     'rating': 3500,
#     'tags': ['data structures', 'greedy', 'math', 'sortings']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 72,
#    'timeConsumedMillis': 1153,
#    'memoryConsumedBytes': 180224000},
#   {'id': 146127666,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644681571,
#    'relativeTimeSeconds': 5071,
#    'problem': {'contestId': 1637,
#     'index': 'G',
#     'name': 'Birthday',
#     'type': 'PROGRAMMING',
#     'points': 4000.0,
#     'rating': 3000,
#     'tags': ['constructive algorithms', 'greedy', 'math']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 63,
#    'timeConsumedMillis': 62,
#    'memoryConsumedBytes': 7782400},
#   {'id': 146102047,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644678795,
#    'relativeTimeSeconds': 2295,
#    'problem': {'contestId': 1637,
#     'index': 'F',
#     'name': 'Towers',
#     'type': 'PROGRAMMING',
#     'points': 3250.0,
#     'rating': 2500,
#     'tags': ['constructive algorithms',
#      'dfs and similar',
#      'dp',
#      'greedy',
#      'trees']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 123,
#    'timeConsumedMillis': 249,
#    'memoryConsumedBytes': 12083200},
#   {'id': 146093750,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644678069,
#    'relativeTimeSeconds': 1569,
#    'problem': {'contestId': 1637,
#     'index': 'E',
#     'name': 'Best Pair',
#     'type': 'PROGRAMMING',
#     'points': 2500.0,
#     'rating': 2100,
#     'tags': ['binary search', 'brute force', 'implementation']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 73,
#    'timeConsumedMillis': 545,
#    'memoryConsumedBytes': 26726400},
#   {'id': 146083055,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644677231,
#    'relativeTimeSeconds': 731,
#    'problem': {'contestId': 1637,
#     'index': 'D',
#     'name': 'Yet Another Minimization Problem',
#     'type': 'PROGRAMMING',
#     'points': 2000.0,
#     'rating': 1800,
#     'tags': ['dp', 'greedy', 'math']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 22,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 0},
#   {'id': 146079146,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644677002,
#    'relativeTimeSeconds': 502,
#    'problem': {'contestId': 1637,
#     'index': 'C',
#     'name': 'Andrew and Stones',
#     'type': 'PROGRAMMING',
#     'points': 1500.0,
#     'rating': 1200,
#     'tags': ['greedy', 'implementation']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 23,
#    'timeConsumedMillis': 31,
#    'memoryConsumedBytes': 409600},
#   {'id': 146075981,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644676859,
#    'relativeTimeSeconds': 359,
#    'problem': {'contestId': 1637,
#     'index': 'C',
#     'name': 'Andrew and Stones',
#     'type': 'PROGRAMMING',
#     'points': 1500.0,
#     'rating': 1200,
#     'tags': ['greedy', 'implementation']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'WRONG_ANSWER',
#    'testset': 'PRETESTS',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 102400},
#   {'id': 146071731,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644676688,
#    'relativeTimeSeconds': 188,
#    'problem': {'contestId': 1637,
#     'index': 'B',
#     'name': 'MEX and Array',
#     'type': 'PROGRAMMING',
#     'points': 1000.0,
#     'rating': 1100,
#     'tags': ['brute force', 'dp', 'greedy', 'math']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 14,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 0},
#   {'id': 146069953,
#    'contestId': 1637,
#    'creationTimeSeconds': 1644676585,
#    'relativeTimeSeconds': 85,
#    'problem': {'contestId': 1637,
#     'index': 'A',
#     'name': 'Sorting Parts',
#     'type': 'PROGRAMMING',
#     'points': 500.0,
#     'rating': 800,
#     'tags': ['brute force', 'sortings']},
#    'author': {'contestId': 1637,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'room': 324,
#     'startTimeSeconds': 1644676500},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'OK',
#    'testset': 'TESTS',
#    'passedTestCount': 12,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 102400},
#   {'id': 145292703,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067777,
#    'relativeTimeSeconds': 12577,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 109,
#    'memoryConsumedBytes': 614400,
#    'points': 180.464},
#   {'id': 145290446,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067619,
#    'relativeTimeSeconds': 12419,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++20 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 3744,
#    'memoryConsumedBytes': 921600,
#    'points': 80.184},
#   {'id': 145290432,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067618,
#    'relativeTimeSeconds': 12418,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 77,
#    'memoryConsumedBytes': 0,
#    'points': 85.792},
#   {'id': 145290424,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067618,
#    'relativeTimeSeconds': 12418,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 108,
#    'memoryConsumedBytes': 0,
#    'points': 94.516},
#   {'id': 145290417,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067617,
#    'relativeTimeSeconds': 12417,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 108,
#    'memoryConsumedBytes': 0,
#    'points': 93.373},
#   {'id': 145290415,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067617,
#    'relativeTimeSeconds': 12417,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 171,
#    'memoryConsumedBytes': 0,
#    'points': 92.377},
#   {'id': 145290412,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067617,
#    'relativeTimeSeconds': 12417,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 140,
#    'memoryConsumedBytes': 0,
#    'points': 84.304},
#   {'id': 145290409,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067617,
#    'relativeTimeSeconds': 12417,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 124,
#    'memoryConsumedBytes': 0,
#    'points': 69.299},
#   {'id': 145290405,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067616,
#    'relativeTimeSeconds': 12416,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 124,
#    'memoryConsumedBytes': 0,
#    'points': 72.568},
#   {'id': 145290394,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067616,
#    'relativeTimeSeconds': 12416,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 140,
#    'memoryConsumedBytes': 0,
#    'points': 89.335},
#   {'id': 145290391,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067616,
#    'relativeTimeSeconds': 12416,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 77,
#    'memoryConsumedBytes': 0,
#    'points': 90.98},
#   {'id': 145290389,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067615,
#    'relativeTimeSeconds': 12415,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 124,
#    'memoryConsumedBytes': 0,
#    'points': 58.694},
#   {'id': 145290382,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067615,
#    'relativeTimeSeconds': 12415,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 124,
#    'memoryConsumedBytes': 0,
#    'points': 86.803},
#   {'id': 145290381,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067615,
#    'relativeTimeSeconds': 12415,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 108,
#    'memoryConsumedBytes': 0,
#    'points': 86.398},
#   {'id': 145290373,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067615,
#    'relativeTimeSeconds': 12415,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 93,
#    'memoryConsumedBytes': 0,
#    'points': 72.568},
#   {'id': 145290368,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067614,
#    'relativeTimeSeconds': 12414,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 92,
#    'memoryConsumedBytes': 0,
#    'points': 81.618},
#   {'id': 145290367,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067614,
#    'relativeTimeSeconds': 12414,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 171,
#    'memoryConsumedBytes': 0,
#    'points': 62.815},
#   {'id': 145290365,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067614,
#    'relativeTimeSeconds': 12414,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 77,
#    'memoryConsumedBytes': 0,
#    'points': 94.565},
#   {'id': 145290350,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067613,
#    'relativeTimeSeconds': 12413,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 77,
#    'memoryConsumedBytes': 0,
#    'points': 91.417},
#   {'id': 145290347,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067613,
#    'relativeTimeSeconds': 12413,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 108,
#    'memoryConsumedBytes': 0,
#    'points': 87.639},
#   {'id': 145290342,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067613,
#    'relativeTimeSeconds': 12413,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 139,
#    'memoryConsumedBytes': 0,
#    'points': 72.078},
#   {'id': 145289267,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067509,
#    'relativeTimeSeconds': 12309,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 171,
#    'memoryConsumedBytes': 0,
#    'points': 25.74},
#   {'id': 145288887,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067468,
#    'relativeTimeSeconds': 12268,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 280,
#    'memoryConsumedBytes': 0,
#    'points': 23.618},
#   {'id': 145288886,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067468,
#    'relativeTimeSeconds': 12268,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 202,
#    'memoryConsumedBytes': 0,
#    'points': 18.761},
#   {'id': 145288884,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067468,
#    'relativeTimeSeconds': 12268,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 186,
#    'memoryConsumedBytes': 0,
#    'points': 24.298},
#   {'id': 145288882,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067467,
#    'relativeTimeSeconds': 12267,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 249,
#    'memoryConsumedBytes': 0,
#    'points': 33.421},
#   {'id': 145288881,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067467,
#    'relativeTimeSeconds': 12267,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 249,
#    'memoryConsumedBytes': 0,
#    'points': 6.799},
#   {'id': 145288880,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067467,
#    'relativeTimeSeconds': 12267,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 264,
#    'memoryConsumedBytes': 0,
#    'points': 23.183},
#   {'id': 145288879,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067466,
#    'relativeTimeSeconds': 12266,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 249,
#    'memoryConsumedBytes': 0,
#    'points': 13.881},
#   {'id': 145288867,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067466,
#    'relativeTimeSeconds': 12266,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 234,
#    'memoryConsumedBytes': 0,
#    'points': 30.555},
#   {'id': 145288856,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067466,
#    'relativeTimeSeconds': 12266,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 233,
#    'memoryConsumedBytes': 0,
#    'points': 35.442},
#   {'id': 145288855,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067466,
#    'relativeTimeSeconds': 12266,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 218,
#    'memoryConsumedBytes': 0,
#    'points': 35.029},
#   {'id': 145288854,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067465,
#    'relativeTimeSeconds': 12265,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 218,
#    'memoryConsumedBytes': 0,
#    'points': 20.873},
#   {'id': 145288852,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067465,
#    'relativeTimeSeconds': 12265,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 202,
#    'memoryConsumedBytes': 0,
#    'points': 36.435},
#   {'id': 145288851,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067465,
#    'relativeTimeSeconds': 12265,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 265,
#    'memoryConsumedBytes': 0,
#    'points': 22.928},
#   {'id': 145288850,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067464,
#    'relativeTimeSeconds': 12264,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 202,
#    'memoryConsumedBytes': 0,
#    'points': 4.214},
#   {'id': 145288848,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067464,
#    'relativeTimeSeconds': 12264,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 155,
#    'memoryConsumedBytes': 0,
#    'points': 28.721},
#   {'id': 145288831,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067464,
#    'relativeTimeSeconds': 12264,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 202,
#    'memoryConsumedBytes': 0,
#    'points': 15.392},
#   {'id': 145288827,
#    'contestId': 1639,
#    'creationTimeSeconds': 1644067463,
#    'relativeTimeSeconds': 12263,
#    'problem': {'contestId': 1639,
#     'index': 'F',
#     'name': 'Treasure Hunt',
#     'type': 'PROGRAMMING',
#     'tags': ['graphs', 'interactive']},
#    'author': {'contestId': 1639,
#     'members': [{'handle': 'tourist'},
#      {'handle': 'pashka'},
#      {'handle': 'Nebuchadnezzar'}],
#     'participantType': 'CONTESTANT',
#     'teamId': 97143,
#     'teamName': 'itmo.algo.teaching',
#     'ghost': False,
#     'startTimeSeconds': 1644055200},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS5',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 233,
#    'memoryConsumedBytes': 0,
#    'points': 9.942},
#   {'id': 145288817,
# ...
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 16082,
#    'memoryConsumedBytes': 62976000,
#    'points': 0.0,
#    'pointsInfo': '10347/10168.78802'},
#   {'id': 117821826,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336600,
#    'relativeTimeSeconds': 335000,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 20000,
#    'memoryConsumedBytes': 63283200,
#    'points': 0.0,
#    'pointsInfo': '0/0.00000'},
#   {'id': 117821824,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336595,
#    'relativeTimeSeconds': 334995,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 20000,
#    'memoryConsumedBytes': 63692800,
#    'points': 0.0,
#    'pointsInfo': '0/0.00000'},
#   {'id': 117821822,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336590,
#    'relativeTimeSeconds': 334990,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 20000,
#    'memoryConsumedBytes': 63180800,
#    'points': 0.0,
#    'pointsInfo': '0/0.00000'},
#   {'id': 117821821,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336585,
#    'relativeTimeSeconds': 334985,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 15989,
#    'memoryConsumedBytes': 62976000,
#    'points': 0.0,
#    'pointsInfo': '10403/10227.06414'},
#   {'id': 117821805,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336520,
#    'relativeTimeSeconds': 334920,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17721,
#    'memoryConsumedBytes': 63180800,
#    'points': 0.0,
#    'pointsInfo': '10386/10209.34158'},
#   {'id': 117821747,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336384,
#    'relativeTimeSeconds': 334784,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19281,
#    'memoryConsumedBytes': 63692800,
#    'points': 0.0,
#    'pointsInfo': '10410/10232.49686'},
#   {'id': 117821745,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336379,
#    'relativeTimeSeconds': 334779,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19312,
#    'memoryConsumedBytes': 63692800,
#    'points': 0.0,
#    'pointsInfo': '10398/10220.61988'},
#   {'id': 117821741,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336374,
#    'relativeTimeSeconds': 334774,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19421,
#    'memoryConsumedBytes': 63488000,
#    'points': 0.0,
#    'pointsInfo': '10352/10174.22179'},
#   {'id': 117821739,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336368,
#    'relativeTimeSeconds': 334768,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19500,
#    'memoryConsumedBytes': 63488000,
#    'points': 0.0,
#    'pointsInfo': '10394/10217.61499'},
#   {'id': 117821736,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336360,
#    'relativeTimeSeconds': 334760,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19483,
#    'memoryConsumedBytes': 63795200,
#    'points': 0.0,
#    'pointsInfo': '10377/10197.56756'},
#   {'id': 117821730,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336347,
#    'relativeTimeSeconds': 334747,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19421,
#    'memoryConsumedBytes': 64102400,
#    'points': 0.0,
#    'pointsInfo': '10346/10168.34612'},
#   {'id': 117821655,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336164,
#    'relativeTimeSeconds': 334564,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17940,
#    'memoryConsumedBytes': 64716800,
#    'points': 0.0,
#    'pointsInfo': '10699/10521.89161'},
#   {'id': 117821636,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336123,
#    'relativeTimeSeconds': 334523,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17986,
#    'memoryConsumedBytes': 65228800,
#    'points': 0.0,
#    'pointsInfo': '10793/10620.39374'},
#   {'id': 117821611,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336080,
#    'relativeTimeSeconds': 334480,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17534,
#    'memoryConsumedBytes': 65024000,
#    'points': 0.0,
#    'pointsInfo': '21568/21564.90300'},
#   {'id': 117821592,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622336051,
#    'relativeTimeSeconds': 334451,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 4321,
#    'memoryConsumedBytes': 62361600,
#    'points': 0.0,
#    'pointsInfo': '10408/10230.32996'},
#   {'id': 117821431,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335633,
#    'relativeTimeSeconds': 334033,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17472,
#    'memoryConsumedBytes': 64512000,
#    'points': 0.0,
#    'pointsInfo': '21751/21750.17426'},
#   {'id': 117821409,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335574,
#    'relativeTimeSeconds': 333974,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17892,
#    'memoryConsumedBytes': 65126400,
#    'points': 0.0,
#    'pointsInfo': '10658/10485.49926'},
#   {'id': 117821385,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335519,
#    'relativeTimeSeconds': 333919,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 17082,
#    'memoryConsumedBytes': 62566400,
#    'points': 0.0,
#    'pointsInfo': '22100/22100.00000'},
#   {'id': 117821371,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335471,
#    'relativeTimeSeconds': 333871,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 1669,
#    'memoryConsumedBytes': 62668800,
#    'points': 0.0,
#    'pointsInfo': '22100/22100.00000'},
#   {'id': 117821349,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335410,
#    'relativeTimeSeconds': 333810,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 1,
#    'timeConsumedMillis': 20000,
#    'memoryConsumedBytes': 62259200,
#    'points': 0.0,
#    'pointsInfo': '0/0.00000'},
#   {'id': 117821333,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335353,
#    'relativeTimeSeconds': 333753,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'RUNTIME_ERROR',
#    'testset': 'TESTS',
#    'passedTestCount': 0,
#    'timeConsumedMillis': 15,
#    'memoryConsumedBytes': 0},
#   {'id': 117821207,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335006,
#    'relativeTimeSeconds': 333406,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19500,
#    'memoryConsumedBytes': 64000000,
#    'points': 0.0,
#    'pointsInfo': '10384/10206.55802'},
#   {'id': 117821206,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622335000,
#    'relativeTimeSeconds': 333400,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19484,
#    'memoryConsumedBytes': 64102400,
#    'points': 0.0,
#    'pointsInfo': '10396/10219.62433'},
#   {'id': 117821204,
#    'contestId': 1524,
#    'creationTimeSeconds': 1622334995,
#    'relativeTimeSeconds': 333395,
#    'problem': {'contestId': 1524,
#     'index': 'A',
#     'name': 'Balanced Regions',
#     'type': 'PROGRAMMING',
#     'tags': ['*special']},
#    'author': {'contestId': 1524,
#     'members': [{'handle': 'tourist'}],
#     'participantType': 'CONTESTANT',
#     'ghost': False,
#     'startTimeSeconds': 1622001600},
#    'programmingLanguage': 'GNU C++17 (64)',
#    'verdict': 'PARTIAL',
#    'testset': 'TESTS',
#    'passedTestCount': 2,
#    'timeConsumedMillis': 19437,
#    'memoryConsumedBytes': 63692800,
#    'points': 0.0,
#    'pointsInfo': '10425/10248.28095'},
#   ...]}

# %%
usr_data = {}

# %%
usr_info = requests.get("https://codeforces.com/api/user.info?handles="+usr).json()
usr_info
# Out:
# {'status': 'OK',
#  'result': [{'lastName': 'Korotkevich',
#    'country': 'Belarus',
#    'lastOnlineTimeSeconds': 1645879120,
#    'city': 'Gomel',
#    'rating': 3946,
#    'friendOfCount': 41464,
#    'titlePhoto': 'https://userpic.codeforces.org/422/title/50a270ed4a722867.jpg',
#    'handle': 'tourist',
#    'avatar': 'https://userpic.codeforces.org/422/avatar/2b5dbe87f0d859a2.jpg',
#    'firstName': 'Gennady',
#    'contribution': 159,
#    'organization': 'ITMO University',
#    'rank': 'legendary grandmaster',
#    'maxRating': 3979,
#    'registrationTimeSeconds': 1265987288,
#    'maxRank': 'legendary grandmaster'}]}

# %%
usr_data['rating'] = usr_info['result'][0]['rating']
usr_data['max_rating'] = usr_info['result'][0]['maxRating']
usr_data['cf_handle'] = usr_info['result'][0]['handle']
usr_data['rank'] = usr_info['result'][0]['rank']

usr_data['category_count'] = {}
usr_data['solved_problems'] = []

# %%
usr_data
# Out:
# {'rating': 3946,
#  'max_rating': 3979,
#  'cf_handle': 'tourist',
#  'rank': 'legendary grandmaster',
#  'category_count': {},
#  'solved_problems': []}

# %%
# adding problems solved data
print(res['result'][0]['problem'])
# Out:
# {'contestId': 1641, 'index': 'D', 'name': 'Two Arrays', 'type': 'PROGRAMMING', 'points': 1750.0, 'tags': ['bitmasks', 'brute force', 'greedy', 'hashing', 'probabilities', 'two pointers']}

# %%
res['result'][0]['verdict']
# Out:
# 'OK'

# %%
for intel in res['result']:
    if intel['verdict'] == 'OK':
        prlbm = intel['problem']
        usr_data['solved_problems'].append(str(prlbm['contestId'])+str(prlbm['index']))
        for tag in prlbm['tags']:
            if tag not in usr_data['category_count']:
                usr_data['category_count'][tag] = {}
                if prlbm['index'] not in usr_data['category_count'][tag]:
                    usr_data['category_count'][tag][prlbm['index']] = 1
                else:
                    usr_data['category_count'][tag][prlbm['index']]+=1
            else:
                if prlbm['index'] not in usr_data['category_count'][tag]:
                    usr_data['category_count'][tag][prlbm['index']] = 1
                else:
                    usr_data['category_count'][tag][prlbm['index']]+=1

# %%
usr_data
# Out:
# {'rating': 3946,
#  'max_rating': 3979,
#  'cf_handle': 'tourist',
#  'rank': 'legendary grandmaster',
#  'category_count': {'bitmasks': {'D': 20,
#    'C': 41,
#    'B': 18,
#    'A': 7,
#    'H': 5,
#    'E': 14,
#    'F': 16,
#    'D1': 1,
#    'G': 6,
#    'J': 15,
#    'I': 1,
#    'F2': 1,
#    'F1': 1,
#    'E2': 1,
#    'E1': 1,
#    'B2': 1},
#   'brute force': {'D': 37,
#    'E': 59,
#    'C': 57,
#    'A': 49,
#    'B': 48,
#    'E1': 4,
#    'F': 12,
#    'E2': 2,
#    'D2': 1,
#    'G': 4,
#    'K': 1,
#    'H': 4,
#    'F1': 1,
#    'I': 2,
#    'G1': 2,
#    'B1': 2,
#    'A1': 1,
#    'D1': 1},
#   'greedy': {'D': 70,
#    'B': 83,
#    'C': 91,
#    'A': 82,
#    'H': 8,
#    'G': 9,
#    'F': 30,
#    'E': 80,
#    'E2': 2,
#    'E1': 2,
#    'D2': 2,
#    'D1': 1,
#    'F2': 1,
#    'F1': 1,
#    'L': 1,
#    'J': 2,
#    'N': 1,
#    'C2': 1,
#    'C1': 2,
#    'H1': 1,
#    'B1': 1,
#    'B2': 1,
#    'G1': 1,
#    'K': 1,
#    'A1': 1,
#    'I': 2},
#   'hashing': {'D': 14,
#    'F': 4,
#    'G': 12,
#    'B': 8,
#    'A': 2,
#    'D1': 1,
#    'D2': 1,
#    'L': 1,
#    'C': 6,
#    'G1': 1,
#    'E': 1,
#    'J': 1},
#   'probabilities': {'D': 21,
#    'E': 11,
#    'F': 3,
#    'B': 8,
#    'H': 2,
#    'D2': 1,
#    'D1': 1,
#    'C': 15,
#    'G': 3,
#    'A': 2,
#    'G2': 3},
#   'two pointers': {'D': 29,
#    'C': 15,
#    'B': 16,
#    'A': 13,
#    'F': 2,
#    'D2': 1,
#    'E': 14,
#    'H': 1,
#    'K': 1,
#    'G': 2,
#    'E2': 1,
#    'E1': 1,
#    'G1': 1},
#   'geometry': {'F': 5,
#    'C': 13,
#    'A': 10,
#    'D': 8,
#    'E': 14,
#    'D2': 1,
#    'D1': 1,
#    'G': 6,
#    'B': 10,
#    'I': 3,
#    'H': 2,
#    'J': 1},
#   'combinatorics': {'E': 31,
#    'D2': 3,
#    'D1': 3,
#    'H': 6,
#    'D': 27,
#    'F': 12,
#    'E1': 1,
#    'B': 15,
#    'C': 23,
#    'I': 2,
#    'A': 6,
#    'G': 8,
#    'H1': 1},
#   'divide and conquer': {'E': 48,
#    'E1': 1,
#    'H': 5,
#    'F': 11,
#    'D': 4,
#    'B': 5,
#    'I': 1,
#    'G': 12,
#    'A': 1,
#    'C': 8,
#    'C2': 1,
#    'B2': 1,
#    'J': 1},
#   'fft': {'E': 11,
#    'F': 2,
#    'C': 1,
#    'I': 1,
#    'H1': 1,
#    'G': 2,
#    'D2': 1,
#    'H': 6,
#    'D': 18},
#   'math': {'E': 52,
#    'C': 73,
#    'B': 86,
#    'A': 99,
#    'H': 15,
#    'G': 28,
#    'D': 81,
#    'D2': 3,
#    'D1': 2,
#    'F': 38,
#    'E2': 2,
#    'E1': 2,
#    'I': 6,
#    'C2': 2,
#    'C1': 2,
#    'L': 2,
#    'H1': 1,
#    'J': 16,
#    'K': 1,
#    'F2': 1,
#    'U': 1,
#    'T': 1,
#    'M': 2,
#    'S': 1,
#    'R': 1,
#    'Q': 1,
#    'P': 1,
#    'O': 1,
#    'N': 1,
#    'B2': 1,
#    'E3': 1,
#    'D3': 1,
#    'A2': 1},
#   'constructive algorithms': {'B': 55,
#    'D': 48,
#    'A': 44,
#    'G': 12,
#    'F': 18,
#    'C': 47,
#    'H': 7,
#    'E1': 1,
#    'E': 32,
#    'I': 1,
#    'C2': 1,
#    'C1': 3,
#    'J': 19,
#    'B2': 1,
#    'L': 1,
#    'D2': 1,
#    'F3': 1},
#   'implementation': {'B': 89,
#    'E': 27,
#    'D': 48,
#    'C': 62,
#    'A': 122,
#    'F': 16,
#    'E2': 1,
#    'G': 6,
#    'D2': 1,
#    'M': 2,
#    'I': 2,
#    'K': 2,
#    'N': 1,
#    'C2': 1,
#    'G1': 1,
#    'H': 4,
#    'D3': 1,
#    'D1': 1,
#    'B1': 1,
#    'A1': 1,
#    'F3': 1,
#    'F1': 1,
#    'J': 1},
#   'sortings': {'B': 34,
#    'C': 39,
#    'A': 29,
#    'H': 2,
#    'F': 8,
#    'D': 35,
#    'E': 23,
#    'D2': 1,
#    'D1': 1,
#    'G': 4,
#    'F1': 1,
#    'F2': 1,
#    'B2': 1,
#    'E2': 1,
#    'E1': 1,
#    'K': 1,
#    'A2': 1,
#    'J': 1},
#   'binary search': {'C': 35,
#    'E': 33,
#    'E1': 2,
#    'E2': 10,
#    'D': 29,
#    'B': 36,
#    'F': 14,
#    'A': 17,
#    'H': 6,
#    'G': 3,
#    'L': 1,
#    'K': 1,
#    'D2': 1,
#    'B2': 1,
#    'J': 1},
#   'data structures': {'C': 42,
#    'E': 93,
#    'D': 61,
#    'B': 38,
#    'H': 13,
#    'E1': 4,
#    'F': 51,
#    'E2': 12,
#    'G': 23,
#    'A': 15,
#    'D2': 2,
#    'D1': 1,
#    'M': 1,
#    'C2': 1,
#    'I': 2,
#    'B1': 1,
#    'B2': 2,
#    'G1': 1,
#    'D3': 1,
#    'A2': 1,
#    'E3': 1},
#   'dsu': {'C': 17,
#    'E': 14,
#    'D': 16,
#    'F': 7,
#    'G': 2,
#    'B': 8,
#    'J': 1,
#    'A': 7,
#    'H': 2,
#    'G1': 1},
#   'graphs': {'C': 31,
#    'E1': 2,
#    'E2': 9,
#    'H': 7,
#    'G': 16,
#    'F': 32,
#    'D': 49,
#    'E': 73,
#    'A': 27,
#    'B': 24,
#    'I': 3,
#    'F2': 1,
#    'F1': 1,
#    'M': 1,
#    'J': 2,
#    'L': 1,
#    'D2': 2},
#   'dfs and similar': {'F': 11,
#    'E1': 2,
#    'E2': 10,
#    'H': 2,
#    'C': 25,
#    'G': 8,
#    'D': 34,
#    'E': 83,
#    'A': 22,
#    'I': 4,
#    'F2': 1,
#    'F1': 2,
#    'B': 19,
#    'L': 1,
#    'G1': 2,
#    'D1': 4,
#    'F3': 1,
#    'B2': 1,
#    'B1': 1},
#   'dp': {'F': 30,
#    'D': 79,
#    'B': 52,
#    'C': 87,
#    'D2': 2,
#    'D1': 4,
#    'E1': 4,
#    'G': 19,
#    'E': 68,
#    'H': 16,
#    'A': 19,
#    'E2': 4,
#    'I': 4,
#    'C2': 3,
#    'C1': 4,
#    'F2': 2,
#    'J': 16,
#    'H1': 1,
#    'F1': 1,
#    'B1': 1,
#    'G3': 1,
#    'G2': 3,
#    'G1': 2,
#    'C3': 1,
#    'D3': 1,
#    'B2': 1},
#   'trees': {'F': 19,
#    'E1': 2,
#    'E2': 11,
#    'E': 85,
#    'D': 33,
#    'H': 7,
#    'I': 2,
#    'B': 11,
#    'C': 23,
#    'A': 8,
#    'G': 10,
#    'L': 1,
#    'D3': 1},
#   'shortest paths': {'E1': 1,
#    'E2': 1,
#    'A': 3,
#    'H': 2,
#    'F': 15,
#    'G': 3,
#    'E': 9,
#    'D': 9,
#    'C': 7,
#    'B': 6},
#   'number theory': {'D': 14,
#    'E': 13,
#    'F': 18,
#    'C': 18,
#    'A': 22,
#    'B': 20,
#    'D2': 2,
#    'D1': 1,
#    'H': 7,
#    'G': 12,
#    'L': 1,
#    'K': 1},
#   'games': {'D2': 1,
#    'D1': 1,
#    'E': 9,
#    'I': 1,
#    'B': 8,
#    'G': 4,
#    'F': 3,
#    'H': 2,
#    'A': 3,
#    'C': 10,
#    'D': 4},
#   'interactive': {'C': 6,
#    'G': 2,
#    'D': 8,
#    'E': 6,
#    'H': 2,
#    'B': 5,
#    'A': 1,
#    'F': 7},
#   'strings': {'B': 21,
#    'E': 19,
#    'G': 9,
#    'C': 19,
#    'A': 21,
#    'D': 9,
#    'F': 12,
#    'I': 1,
#    'D1': 1,
#    'D2': 1,
#    'H': 3,
#    'G1': 1,
#    'J': 1},
#   'matrices': {'F': 3, 'E': 8, 'C': 4, 'B': 1, 'D': 4, 'A': 2},
#   'flows': {'H': 3,
#    'D': 2,
#    'I': 2,
#    'G': 4,
#    'B': 2,
#    'F': 2,
#    'H1': 1,
#    'E': 38,
#    'J': 1,
#    'F2': 1,
#    'F1': 1,
#    'C': 2,
#    'C2': 1,
#    'C1': 1,
#    'A': 1},
#   'graph matchings': {'G': 2,
#    'D': 4,
#    'I': 1,
#    'B': 2,
#    'F': 3,
#    'E': 2,
#    'C': 13,
#    'C2': 1,
#    'H': 1},
#   'meet-in-the-middle': {'F': 3, 'E': 1, 'L': 1, 'F1': 1, 'D': 7, 'G1': 2},
#   'schedules': {'C': 1, 'E': 1},
#   'string suffix structures': {'G': 9,
#    'D1': 1,
#    'D2': 1,
#    'H': 1,
#    'D': 5,
#    'F': 2,
#    'C': 3,
#    'E': 2,
#    'G2': 1,
#    'B': 2},
#   '*special': {'G': 12,
#    'F': 17,
#    'E': 22,
#    'D': 24,
#    'C': 26,
#    'B': 27,
#    'A': 25,
#    'J': 2,
#    'I': 9,
#    'H': 12,
#    'F1': 1,
#    'F2': 1,
#    'E3': 1,
#    'E2': 1,
#    'E1': 1},
#   'ternary search': {'C': 4, 'B': 2, 'E': 2},
#   '2-sat': {'D': 2, 'F': 1},
#   'chinese remainder theorem': {'B': 2, 'A': 1, 'H': 5, 'D': 1},
#   'expression parsing': {'F': 4, 'A': 2, 'C': 1, 'D': 1, 'B': 3}},
#  'solved_problems': ['1641D',
#   '1641D',
#   '1641D',
#   '1641F',
#   '1641E',
#   '1641B',
#   '1641C',
#   '1641D',
#   '1641A',
#   '1638E',
#   '1638D',
#   '1638C',
#   '1638B',
#   '1638A',
#   '1637H',
#   '1637G',
#   '1637F',
#   '1637E',
#   '1637D',
#   '1637C',
#   '1637B',
#   '1637A',
#   '1632E1',
#   '1632E2',
#   '1632D',
#   '1632C',
#   '1632B',
#   '1632A',
#   '1630E',
#   '1630D',
#   '1630C',
#   '1630B',
#   '1630A',
#   '1628F',
#   '1628E',
#   '1628D2',
#   '1628D1',
#   '1628C',
#   '1628B',
#   '1628A',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E2',
#   '1625E1',
#   '1625D',
#   '1625C',
#   '1625B',
#   '1625A',
#   '3A',
#   '1621H',
#   '1621G',
#   '1621F',
#   '1621E',
#   '1621D',
#   '1621C',
#   '1621B',
#   '1621A',
#   '1616G',
#   '1616H',
#   '1616F',
#   '1616D',
#   '1616C',
#   '1616E',
#   '1616B',
#   '1616A',
#   '1622F',
#   '1622E',
#   '1622D',
#   '1622C',
#   '1622B',
#   '1622A',
#   '1615H',
#   '1615F',
#   '1615G',
#   '1615D',
#   '1615E',
#   '1615C',
#   '1615A',
#   '1615B',
#   '1609H',
#   '1609G',
#   '1609F',
#   '1609E',
#   '1609D',
#   '1609C',
#   '1609B',
#   '1609A',
#   '1610H',
#   '1610F',
#   '1610I',
#   '1610G',
#   '1610E',
#   '1610D',
#   '1610C',
#   '1610B',
#   '1610A',
#   '103104K',
#   '103104B',
#   '103104E',
#   '103104C',
#   '103104G',
#   '103104H',
#   '103104I',
#   '103104D',
#   '103104A',
#   '103104F',
#   '1603D',
#   '1603E',
#   '1603C',
#   '1603B',
#   '1603A',
#   '1598G',
#   '1598F',
#   '1598E',
#   '1598D',
#   '1598C',
#   '1598B',
#   '1598A',
#   '1594A',
#   '1594B',
#   '1594C',
#   '1594D',
#   '1594E2',
#   '1594E1',
#   '1594F',
#   '1570G',
#   '1570F',
#   '1570E',
#   '1570D',
#   '1570C',
#   '1570B',
#   '1570A',
#   '1579G',
#   '1579F',
#   '1579E2',
#   '1579E1',
#   '1579D',
#   '1579C',
#   '1579B',
#   '1579A',
#   '1574F',
#   '1574E',
#   '1574D',
#   '1574C',
#   '1574B',
#   '1574A',
#   '1572E',
#   '1572B',
#   '1572C',
#   '1572D',
#   '1572A',
#   '1566G',
#   '1566E',
#   '1566F',
#   '1566D2',
#   '1566D1',
#   '1566C',
#   '1566B',
#   '1566A',
#   '1556E',
#   '1556F',
#   '1556D',
#   '1556C',
#   '1556B',
#   '1556A',
#   '1557E',
#   '1557D',
#   '1557C',
#   '1557B',
#   '1557A',
#   '1554A',
#   '1548E',
#   '1548D2',
#   '1548C',
#   '1548D1',
#   '1548B',
#   '1548A',
#   '1555F',
#   '1555F',
#   '1555E',
#   '1555D',
#   '1555C',
#   '1555B',
#   '1555A',
#   '1552H',
#   '1552F',
#   '1552E',
#   '1552G',
#   '1552I',
#   '1552D',
#   '1552C',
#   '1552B',
#   '1552A',
#   '1553I',
#   '1553H',
#   '1553G',
#   '1553F',
#   '1553E',
#   '1553D',
#   '1553A',
#   '1553B',
#   '1553C',
#   '1533J',
#   '1533I',
#   '1533G',
#   '1533H',
#   '1533F',
#   '1533E',
#   '1533D',
#   '1533C',
#   '1533B',
#   '1533A',
#   '1532F',
#   '1532E',
#   '1532D',
#   '1532C',
#   '1532B',
#   '1532A',
#   '1540D',
#   '1540C2',
#   '1540C1',
#   '1540B',
#   '1540A',
#   '1539D',
#   '1539C',
#   '1539B',
#   '1539A',
#   '1539F',
#   '1534F2',
#   '1534G',
#   '1534H',
#   '1534F1',
#   '1534E',
#   '1534D',
#   '1534C',
#   '1534B',
#   '1534A',
#   '1523F',
#   '1523F',
#   '1523G',
#   '1523D',
#   '1523E',
#   '1523C',
#   '1523B',
#   '1523A',
#   '1528E',
#   '1528D',
#   '1528C',
#   '1528B',
#   '1528A',
#   '1515F',
#   '1515G',
#   '1515E',
#   '1515D',
#   '1515C',
#   '1515B',
#   '1515A',
#   '1517F',
#   '1517E',
#   '1517D',
#   '1517C',
#   '1517B',
#   '1517A',
#   '1508E',
#   '1508D',
#   '1508C',
#   '1508B',
#   '1508A',
#   '1503E',
#   '1503D',
#   '1503C',
#   '1503B',
#   '1503A',
#   '1505I',
#   '1505F',
#   '1505B',
#   '1505C',
#   '1505H',
#   '1505E',
#   '1505A',
#   '1500F',
#   '1500E',
#   '1500C',
#   '1500A',
#   '1500B',
#   '1495E',
#   '1495F',
#   '1495C',
#   '1495B',
#   '1495D',
#   '1495A',
#   '1488I',
#   '1488H',
#   '1488G',
#   '1488F',
#   '1488E',
#   '1488D',
#   '1488C',
#   '1488B',
#   '1488A',
#   '1491G',
#   '1491E',
#   '1491C',
#   '1491F',
#   '1491D',
#   '1491B',
#   '1491A',
#   '1477D',
#   '1477E',
#   '1477C',
#   '1477B',
#   '1477A',
#   '1475G',
#   '1475F',
#   '1475E',
#   '1475D',
#   '1475C',
#   '1475B',
#   '1475A',
#   '1470E',
#   '1470C',
#   '1470D',
#   '1470B',
#   '1470A',
#   '1466H',
#   '1466G',
#   '1466F',
#   '1466E',
#   '1466D',
#   '1466C',
#   '1466B',
#   '1466A',
#   '1468B',
#   '1468M',
#   '1468G',
#   '1468L',
#   '1468I',
#   '1468H',
#   '1468J',
#   '1468A',
#   '1468K',
#   '1468D',
#   '1468C',
#   '1468F',
#   '1468N',
#   '1468E',
#   '1464E',
#   '1464C',
#   '1464B',
#   '1464A',
#   '1458C',
#   '1458D',
#   '1458E',
#   '1458B',
#   '1458A',
#   '1450G',
#   '1450H1',
#   '1450E',
#   '1450F',
#   '1450C2',
#   '1450C1',
#   '1450D',
#   '1450B',
#   '1450A',
#   '996B',
#   '996A',
#   '995F',
#   '995C',
#   '995D',
#   '995E',
#   '995B',
#   '995A',
#   '1431I',
#   '1431J',
#   '1431H',
#   '1431G',
#   '1431F',
#   '1431E',
#   '1431D',
#   '1431C',
#   '1431B',
#   '1431A',
#   '1432F',
#   '1432E',
#   '1432D',
#   '1432C',
#   '1432B',
#   '1432A',
#   '1441E',
#   '1441A',
#   '1441D',
#   '1441B',
#   '1441C',
#   '1434E',
#   '1434C',
#   '1434B',
#   '1434A',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '1423J',
#   '818G',
#   '818G',
#   '1427E',
#   '1427D',
#   '1427C',
#   '1427B',
#   '1427A',
#   '1423C',
#   '1423I',
#   '1423F',
#   '1423H',
#   '1423L',
#   '1423J',
#   '1423B',
#   '1423K',
#   '1408H',
#   '1408I',
#   '1408G',
#   '1408E',
#   '1408F',
#   '1408B',
#   '1408D',
#   '1408C',
#   '1408A',
#   '1416F',
#   '1416D',
#   '1416E',
#   '1416B',
#   '1416C',
#   '1416A',
#   '1420E',
#   '1420C2',
#   '1420C1',
#   '1420C1',
#   '1420B',
#   '1420A',
#   '1420D',
#   '1418F',
#   '1418G',
#   '1418E',
#   '1418D',
#   '1418C',
#   '1418B',
#   '1418B',
#   '1418A',
#   '1407E',
#   '1407D',
#   '1407C',
#   '1407B',
#   '1407A',
#   '1404D',
#   '1404C',
#   '1404B',
#   '1404A',
#   '1396E',
#   '1396D',
#   '1396C',
#   '1396B',
#   '1396A',
#   '1392F',
#   '1392G',
#   '1392H',
#   '1392E',
#   '1392D',
#   '1392C',
#   '1392B',
#   '1392A',
#   '1394D',
#   '1394B',
#   '1394A',
#   '1383F',
#   '1383C',
#   '1383D',
#   '1383E',
#   '1383B',
#   '1383A',
#   '1375H',
#   '1375G',
#   '1375E',
#   '1375F',
#   '1375D',
#   '1375C',
#   '1375B',
#   '1375A',
#   '1368H1',
#   '1368F',
#   '1368E',
#   '1368G',
#   '1368D',
#   '1368C',
#   '1368B',
#   '1368A',
#   '1361F',
#   '1361D',
#   '1361E',
#   '1361C',
#   '1361B',
#   '1361A',
#   '1346H',
#   '1346I',
#   '1346G',
#   '1346F',
#   '1346E',
#   '1346D',
#   '1346C',
#   '1346B',
#   '1346A',
#   '1347E',
#   '1347D',
#   '1347C',
#   '1347B',
#   '1347A',
#   '1344E',
#   '1349B',
#   '1349C',
#   '1349A',
#   '1344E',
#   '1344E',
#   '1344F',
#   '1344D',
#   '1344C',
#   '1344B',
#   '1344A',
#   '1340C',
#   '1340D',
#   '1340A',
#   '1340B',
#   '1336D',
#   '1336C',
#   '1336B',
#   '1336A',
#   '1335F',
#   '1335E2',
#   '1335E1',
#   '1335D',
#   '1335C',
#   '1335A',
#   '1335B',
#   '1338E',
#   '1338D',
#   '1338C',
#   '1338B',
#   '1338A',
#   '1329D',
#   '1329C',
#   '1329A',
#   '1329B',
#   '1331B',
#   '1331H',
#   '1331G',
#   '1331E',
#   '1331D',
#   '1331C',
#   '1331F',
#   '1331A',
#   '1326F2',
#   '1326E',
#   '1326F1',
#   '1326D1',
#   '1326D2',
#   '1326C',
#   '1326B',
#   '1326A',
#   '1305H',
#   '1305F',
#   '1305D',
#   '1305E',
#   '1305B',
#   '1305C',
#   '1305A',
#   '1297I',
#   '1297G',
#   '1297H',
#   '1297E',
#   '1297F',
#   '1297D',
#   '1297C',
#   '1297B',
#   '1297A',
#   '1310B',
#   '1310D',
#   '1298F1',
#   '1298F2',
#   '1298E',
#   '1298E',
#   '1298D',
#   '1298D',
#   '1298C',
#   '1298C',
#   '1298C',
#   '1298B',
#   '1298B',
#   '1298A',
#   '1310F',
#   '1310C',
#   '1310D',
#   '1310E',
#   '1310A',
#   '1307E',
#   '1307D',
#   '1307C',
#   '1307B',
#   '1307A',
#   '1302J',
#   '1302F',
#   '1302H',
#   '1302E',
#   '1302D',
#   '1302B',
#   '1302C',
#   '1302A',
#   '1290C',
#   '1290D',
#   '1290C',
#   '1290F',
#   '1290A',
#   '1290B',
#   '1292E',
#   '1292C',
#   '1292D',
#   '1292B',
#   '1292A',
#   '1284F',
#   '1284E',
#   '1284D',
#   '1284A',
#   '1284C',
#   '1284B',
#   '1270D',
#   '1270F',
#   '1270C',
#   '1270E',
#   '1270B',
#   '1270A',
#   '1268E',
#   '1268D',
#   '1268C',
#   '1268B',
#   '1268A',
#   '1266F',
#   '1266E',
#   '1266D',
#   '1266C',
#   '1266B',
#   '1266A',
#   '1275E3',
#   '1275E2',
#   '1275E1',
#   '1275D',
#   '1275B',
#   '1275A',
#   '1275C',
#   '1275F',
#   '1264E',
#   '1264D2',
#   '1264D1',
#   '1264C',
#   '1264A',
#   '1264B',
#   '1261F',
#   '1261F',
#   '1261F',
#   '1261F',
#   '1261C',
#   '1261E',
#   '1261D1',
#   '1261D2',
#   '1261B1',
#   '1261B2',
#   '1261A',
#   '1246F',
#   '1246D',
#   '1246C',
#   '1246A',
#   '1246B',
#   '575C',
#   '1209F',
#   '1209G1',
#   '1209E2',
#   '1209E1',
#   '1209D',
#   '1209C',
#   '1209B',
#   '1209A',
#   '1211I',
#   '1211H',
#   '1211G',
#   '1211F',
#   '1211E',
#   '1211D',
#   '1211C',
#   '1211B',
#   '1211A',
#   '1212H',
#   '1212F',
#   '1212G',
#   '1212B',
#   '1212E',
#   '1212D',
#   '1212C',
#   '1212B',
#   '1212A',
#   '1208H',
#   '1208G',
#   '1208F',
#   '1208E',
#   '1208C',
#   '1208D',
#   '1208B',
#   '1208A',
#   '1043D',
#   '1043D',
#   '1198F',
#   '1198D',
#   '1198E',
#   '1198B',
#   '1198C',
#   '1198A',
#   '1148G',
#   '1148G',
#   '1148E',
#   '1148F',
#   '1148D',
#   '1148B',
#   '1148C',
#   '1148A',
#   '1170I',
#   '1170G',
#   '1170H',
#   '1170E',
#   '1170F',
#   '1170D',
#   '1170C',
#   '1170B',
#   '1170A',
#   '1164U',
#   '1164T',
#   '1164L',
#   '1164I',
#   '1164F',
#   '1164M',
#   '1164B',
#   '1164D',
#   '1164C',
#   '1164S',
#   '1164H',
#   '1164R',
#   '1164Q',
#   '1164P',
#   '1164O',
#   '1164N',
#   '1164J',
#   '1164G',
#   '1164E',
#   '1164A',
#   '1146H',
#   '1146F',
#   '1146G',
#   '1146E',
#   '1146D',
#   '1146C',
#   '1146B',
#   '1146A',
#   '1119F',
#   '1119E',
#   '1119D',
#   '1119C',
#   '1119B',
#   '1119A',
#   '1116D5',
#   '1116D4',
#   '1116B1',
#   '1116A1',
#   '1116D4',
#   '1116D3',
#   '1116A2',
#   '1116D2',
#   '1116A1',
#   '1116C3',
#   '1116C2',
#   '1116C2',
#   '1116C1',
#   '1116D1',
#   '1110F',
#   '1110G',
#   '1110D',
#   '1110E',
#   '1110C',
#   '1110B',
#   '1110A',
#   '1054H',
#   '1054H',
#   '1054H',
#   '1054H',
#   '1054H',
#   '438E',
#   '438E',
#   '438E',
#   '866G',
#   '866G',
#   '866G',
#   '866G',
#   '866G',
#   '1097H',
#   '1097H',
#   '1097G',
#   '1097G',
#   '1097E',
#   '1097G',
#   '1097F',
#   '1097D',
#   '1097C',
#   '1097B',
#   '1097A',
#   '756F',
#   '756F',
#   '1091H',
#   '1091G',
#   '1091F',
#   '1091E',
#   '1091D',
#   '1091C',
#   '1091B',
#   '1091A',
#   '1081G',
#   '1081F',
#   '1081E',
#   '1081B',
#   '1081D',
#   '1081C',
#   '1081A',
#   '1055D',
#   '1055F',
#   '1055E',
#   '1055C',
#   '1055B',
#   '1055A',
#   '1044E',
#   '1044F',
#   '1044B',
#   '1044D',
#   '1044C',
#   '1044A',
#   '1043G',
#   '1043G',
#   '1043G',
#   '1043G',
#   '1043G',
#   '1043G',
#   '1043G',
#   '1043D',
#   '1043D',
#   '1043D',
#   '1043F',
#   '1043E',
#   '1043C',
#   '1043B',
#   '1043A',
#   '899F',
#   '899F',
#   '847D',
#   '847D',
#   '847D',
#   '847D',
#   '863D',
#   '863D',
#   '762E',
#   '762E',
#   '892E',
#   '892E',
#   '1033E',
#   '1033G',
#   '1033F',
#   '1033D',
#   '1033C',
#   '1033B',
#   '1033A',
#   '1037G',
#   '1037H',
#   '1037E',
#   '1037F',
#   '1037D',
#   '1037C',
#   '1037B',
#   '1037A',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '986D',
#   '1002C2',
#   '1002A4',
#   '1002D3',
#   '1002C1',
#   '1002E2',
#   '1002B4',
#   '1002E1',
#   '1002B3',
#   '1002D2',
#   '1002D1',
#   '1002B2',
#   '1002B1',
#   '1002A3',
#   '1002A2',
#   '1002A1',
#   '1001I',
#   '1001H',
#   '1001G',
#   '1001F',
#   '1001E',
#   '1001D',
#   '1001C',
#   '1001B',
#   '1001A',
#   '986E',
#   '986F',
#   '986C',
#   '986D',
#   '986B',
#   '986A',
#   '981H',
#   '981G',
#   '981F',
#   '981E',
#   '981D',
#   '981C',
#   '981B',
#   '981A',
#   '966C',
#   '966E',
#   '966D',
#   '966A',
#   '966B',
#   '947A',
#   '947C',
#   '947B',
#   '101606K',
#   '101606K',
#   '101606G',
#   '101606H',
#   '101606L',
#   '101606E',
#   '101606B',
#   '101606I',
#   '101606F',
#   '101606D',
#   '101606C',
#   '101606J',
#   '101606A',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '575C',
#   '723E',
#   '508D',
#   '508D',
#   '757F',
#   '757F',
#   '757F',
#   '757F',
#   '860E',
#   '860E',
#   '860E',
#   '860E',
#   '860E',
#   ...]}

# %%
import pickle

file = open('database/'+usr+".pkl", "wb")
pickle.dump(usr_data, file)
file.close()

# %%
usr = "adi_13"
read_file = open("database/"+usr+".pkl", "rb")
all_prob = pickle.load(read_file)
print(all_prob)
# Out:
# {'cf_rating': 1219, 'cf_max_rating': 1253, 'cf_handle': 'adi_13', 'cf_rank': 'pupil', 'category_count': {'geometry': {'A': 1}, 'greedy': {'B': 3, 'A': 2, 'D': 1, 'E1': 1}, 'brute force': {'B': 1, 'A': 1}, 'constructive algorithms': {'B': 1, 'A': 2, 'D': 1, 'E1': 1}, 'implementation': {'B': 3, 'A': 3}, 'bitmasks': {'A': 1}, 'strings': {'B': 1, 'A': 1}, 'math': {'A': 2, 'E1': 1, 'B': 1}, 'number theory': {'A': 1}, 'graphs': {'D': 1}, 'sortings': {'B': 1}, 'combinatorics': {'B': 1}}, 'cf_solved_problems': ['1642A', '1642B', '1644B', '1644A', '1635B', '1635A', '1627A', '1609B', '1609A', '1579D', '1579E1', '1579B', '1579A', '1574B', '1574A']}

# %%
usr = "phoenix_adi"
res=requests.get("https://codeforces.com/api/user.status?handle="+usr).json()
print(res)
# Out:
# {'status': 'FAILED', 'comment': 'handle: User with handle phoenix_adi not found'}

# %%
res = requests.get("https://competitive-coding-api.herokuapp.com/api/spoj/abhijeet_ar").json()
print(res)
# Out:
# {'status': 'Success', 'username': 'abhijeet_ar', 'platform': 'SPOJ', 'points': 5.9, 'rank': 6407, 'solved': ['ADACUT', 'CIRCLE_E', 'PALIN', 'TEST', 'ADATOMAT', 'CIRCLE_H', 'POWERUP', 'THREENUMBERS', 'ADDREV', 'ICKHELLO', 'PRIME1', 'AGGRCOW', 'MINDIFF', 'SBANK', 'APM', 'MINSTACK', 'SQRROOT', 'CBIT01', 'MOHIBPIZ', 'SYNC13C', 'CGBOY', 'OEN', 'TDPRIMES'], 'todo': ['ICKAPLSB', 'SEQPAR'], 'join data': 'Jul 2019', 'institute': 'CVR College of Engineering'}

# %% [markdown]
# ### problem suggestor using username

# %%
usr = "tourist"

read_file = open("database/"+usr+".pkl", "rb")
usr_data = pickle.load(read_file)
print(usr_data)
# Out:
# {'cf_rating': 1219, 'cf_max_rating': 1253, 'cf_handle': 'adi_13', 'cf_rank': 'pupil', 'category_count': {'geometry': {'A': 1}, 'greedy': {'B': 3, 'A': 2, 'D': 1, 'E1': 1}, 'brute force': {'B': 1, 'A': 1}, 'constructive algorithms': {'B': 1, 'A': 2, 'D': 1, 'E1': 1}, 'implementation': {'B': 3, 'A': 3}, 'bitmasks': {'A': 1}, 'strings': {'B': 1, 'A': 1}, 'math': {'A': 2, 'E1': 1, 'B': 1}, 'number theory': {'A': 1}, 'graphs': {'D': 1, 'A': 0, 'B': 0, 'C': 0, 'E': 0, 'F': 0, 'G': 0, 'H': 0}, 'sortings': {'B': 1}, 'combinatorics': {'B': 1}}, 'cf_solved_problems': ['1642A', '1642B', '1644B', '1644A', '1635B', '1635A', '1627A', '1609B', '1609A', '1579D', '1579E1', '1579B', '1579A', '1574B', '1574A']}

# %%
problems = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
level_solved = {}

for difficulty in problems:
    for category in usr_data['category_count']:
#         print(usr_data['category_count'][category])
        if difficulty in usr_data['category_count'][category]:
            if difficulty not in level_solved:
                level_solved[difficulty] = int(usr_data['category_count'][category][difficulty])
            else:
                level_solved[difficulty] += int(usr_data['category_count'][category][difficulty])

# %%
print(level_solved)
# Out:
# {'A': 14, 'B': 12, 'C': 0, 'D': 3, 'E': 0, 'F': 0, 'G': 0, 'H': 0}

# %%
def get_avg_level(level_solved):
    problems = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
    
    sum = 0
    for i in problems:
        if i not in level_solved:
            level_solved[i] = 0
        sum += level_solved[i]
    
    calc = 0
    calc += level_solved['A']*800+level_solved['B']*1000+level_solved['C']*1200
    calc += level_solved['D']*1500 + level_solved['E']*1700+level_solved['F']*2000
    calc += level_solved['G']*2200 + level_solved['H']*2400
    
    return calc/sum+100

# %%
get_avg_level(level_solved)
# Out:
# 1055.1724137931035

# %%
def suggested_q_level(avg_lvl):
    if avg_lvl<800: return 'A'
    if avg_lvl<1000: return 'B'
    if avg_lvl<1200: return 'C'
    if avg_lvl<1500: return 'D'
    if avg_lvl<1700: return 'E'
    if avg_lvl<2000: return 'F'
    if avg_lvl<2200: return 'G'
    else: return 'H'

# %%
suggested_q_level(get_avg_level(level_solved))
# Out:
# 'C'

# %%
read_file = open("../problem_set/problem_set.pkl", "rb")
problem_set = pickle.load(read_file)

# %%
no_of_problems = {}

# %%
all_categories = list(problem_set.keys())

# %%
from random import sample, shuffle
shuffle(all_categories)
# print(all_categories)

# %%
recommended_questions = []

for cat in all_categories:
    person_lvl = 'A'
    if cat in usr_data['category_count']:
        person_lvl = suggested_q_level(get_avg_level(usr_data['category_count'][cat]))
    for q in problem_set[cat]:
        if q[2]==person_lvl and ((str(q[1])+str(q[2])) not in usr_data['cf_solved_problems']):
            if len(recommended_questions)>10:
                break
            
            recommended_questions.append(q)
    if len(recommended_questions)>10:
        break
    

print(len(recommended_questions))
for i in recommended_questions:
    print(i)
# Out:
# 11
# ['Treasure Hunt', 1639, 'E', 'https://codeforces.com/problemset/problem/1639/E']
# ['Cars ', 1635, 'E', 'https://codeforces.com/problemset/problem/1635/E']
# ['Fair Share', 1634, 'E', 'https://codeforces.com/problemset/problem/1634/E']
# ['Spanning Tree Queries', 1633, 'E', 'https://codeforces.com/problemset/problem/1633/E']
# ['Christmas Chocolates', 1617, 'E', 'https://codeforces.com/problemset/problem/1617/E']
# ['Purple Crayon', 1615, 'E', 'https://codeforces.com/problemset/problem/1615/E']
# ['Crazy Robot', 1613, 'E', 'https://codeforces.com/problemset/problem/1613/E']
# ['Moment of Bloom', 1583, 'E', 'https://codeforces.com/problemset/problem/1583/E']
# ['Railway Construction', 1580, 'E', 'https://codeforces.com/problemset/problem/1580/E']
# ['Down Below', 1558, 'E', 'https://codeforces.com/problemset/problem/1558/E']
# ['Permutation Shift', 1553, 'E', 'https://codeforces.com/problemset/problem/1553/E']

# %% [markdown]
# ### getting all data we can from all platforms
